# %% [markdown]
# ## Question 1
# Install Pipenv
# * What's the version of pipenv you installed?
# (Use --version to find out)
#   - Pipenv-2022.10.9

# %% [markdown]
# ## Question 2
# * Use Pipenv to install Scikit-Learn version 1.0.2
# * What's the first hash for scikit-learn you get in Pipfile.lock?

# %% [markdown]
# * pipenv install scikit-learn==1.0.2
# * first hash -![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("the probability that this client will get a credit card is 0.162")
# Out:
# the probability that this client will get a credit card is 0.162

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("the probability that this client will get a credit card is 0.928")
# Out:
# the probability that this client will get a credit card is 0.928

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(" the size of this base image is125MB")
# Out:
#  the size of this base image is125MB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
